# %%
import psutil

def listar_procesos():
    # Obtener la lista de procesos en ejecución
    procesos = psutil.process_iter(attrs=['pid', 'name', 'status', 'num_threads'])

    print(f"{'PID':<10} {'Nombre':<30} {'Estado':<15} {'Hilos':<10}")
    print("=" * 65)

    for proceso in procesos:
        try:
            # Obtener información del proceso
            pid = proceso.info['pid']
            nombre = proceso.info['name']
            estado = proceso.info['status']
            hilos = proceso.info['num_threads']

            # Imprimir información del proceso
            print(f"{pid:<10} {nombre:<30} {estado:<15} {hilos:<10}")
        except (psutil.NoSuchProcess, psutil.AccessDenied):
            # Manejar el caso donde el proceso ya no existe o no se tiene permiso
            continue

if __name__ == "__main__":
    listar_procesos()
# Out:
# PID        Nombre                         Estado          Hilos
# =================================================================
# 0          System Idle Process            running         4
# 4          System                         running         212
# 100        Registry                       running         4
# 372        fontdrvhost.exe                running         5
# 496        smss.exe                       running         2
# 720        csrss.exe                      running         18
# 724        svchost.exe                    running         11
# 836        wininit.exe                    running         1
# 956        services.exe                   running         6
# 972        lsass.exe                      running         9
# 1064       WUDFHost.exe                   running         10
# 1128       svchost.exe                    running         10
# 1176       avp.exe                        running         8
# 1180       svchost.exe                    running         5
# 1212       svchost.exe                    running         2
# 1408       svchost.exe                    running         6
# 1412       svchost.exe                    running         2
# 1424       svchost.exe                    running         7
# 1488       RuntimeBroker.exe              running         14
# 1548       svchost.exe                    running         4
# 1592       svchost.exe                    running         1
# 1664       svchost.exe                    running         2
# 1728       svchost.exe                    running         11
# 1752       svchost.exe                    running         4
# 1788       chrome.exe                     running         16
# 1792       svchost.exe                    running         4
# 1924       svchost.exe                    running         7
# 1976       dasHost.exe                    running         3
# 1992       svchost.exe                    running         2
# 2016       igfxCUIService.exe             running         2
# 2028       svchost.exe                    running         6
# 2088       svchost.exe                    running         1
# 2164       svchost.exe                    running         4
# 2200       svchost.exe                    running         7
# 2208       svchost.exe                    running         1
# 2268       svchost.exe                    running         6
# 2332       svchost.exe                    running         3
# 2340       svchost.exe                    running         3
# 2396       svchost.exe                    running         2
# 2404       svchost.exe                    running         5
# 2440       svchost.exe                    running         2
# 2556       svchost.exe                    running         5
# 2564       chrome.exe                     running         17
# 2588       AggregatorHost.exe             running         2
# 2624       MemCompression                 running         74
# 2708       svchost.exe                    running         11
# 2800       svchost.exe                    running         9
# 2824       RtkAudioService64.exe          running         4
# 2860       svchost.exe                    running         4
# 2948       svchost.exe                    running         4
# 3080       svchost.exe                    running         10
# 3088       svchost.exe                    running         11
# 3212       SecurityHealthService.exe      running         25
# 3252       SystemSettings.exe             stopped         23
# 3268       svchost.exe                    running         4
# 3276       svchost.exe                    running         7
# 3344       svchost.exe                    running         9
# 3392       svchost.exe                    running         3
# 3440       svchost.exe                    running         3
# 3612       svchost.exe                    running         2
# 3620       OUTLOOK.EXE                    running         49
# 3712       svchost.exe                    running         14
# 3804       svchost.exe                    running         4
# 3852       spoolsv.exe                    running         13
# 3888       svchost.exe                    running         1
# 3972       svchost.exe                    running         12
# 4044       dasHost.exe                    running         1
# 4060       chrome.exe                     running         19
# 4080       svchost.exe                    running         5
# 4140       svchost.exe                    running         4
# 4192       svchost.exe                    running         4
# 4200       svchost.exe                    running         3
# 4340       svchost.exe                    running         9
# 4348       svchost.exe                    running         6
# 4356       svchost.exe                    running         18
# 4372       RAVBg64.exe                    running         6
# 4456       svchost.exe                    running         6
# 4468       svchost.exe                    running         3
# 4476       svchost.exe                    running         13
# 4484       svchost.exe                    running         1
# 4580       svchost.exe                    running         9
# 4592       HPSIsvc.exe                    running         3
# 4608       chrome.exe                     running         19
# 4612       svchost.exe                    running         12
# 4616       Emc.Captiva.WebCaptureService.exe running         12
# 4624       avp.exe                        running         146
# 4636       RtkBtManServ.exe               running         2
# 4644       AnyDesk.exe                    running         8
# 4652       XtuService.exe                 running         12
# 4660       NLSSRV32.EXE                   running         2
# 4672       servicehost.exe                running         92
# 4680       esif_uf.exe                    running         3
# 4756       IntelCpHDCPSvc.exe             running         3
# 4764       ETDService.exe                 running         2
# 4772       cfbackd.w32.exe                running         11
# 4828       svchost.exe                    running         4
# 5036       svchost.exe                    running         4
# 5048       LMS.exe                        running         3
# 5076       TeamViewer_Service.exe         running         19
# 5100       svchost.exe                    running         6
# 5108       IntelCpHeciSvc.exe             running         3
# 5132       msedge.exe                     running         7
# 5136       chrome.exe                     running         16
# 5152       svchost.exe                    running         5
# 5372       msedgewebview2.exe             running         16
# 5504       jhi_service.exe                running         2
# 5844       svchost.exe                    running         14
# 5936       PresentationFontCache.exe      running         4
# 5988       Spotify.exe                    running         44
# 6028       OfficeClickToRun.exe           running         20
# 6180       svchost.exe                    running         7
# 6320       SearchIndexer.exe              running         17
# 6472       uihost.exe                     running         61
# 6588       RuntimeBroker.exe              running         1
# 6780       conhost.exe                    running         2
# 7052       ShellExperienceHost.exe        stopped         15
# 7068       pet.exe                        running         1
# 7140       msedgewebview2.exe             running         21
# 7408       Spotify.exe                    running         6
# 7580       Microsoft.SharePoint.exe       running         16
# 7596       svchost.exe                    running         7
# 7608       svchost.exe                    running         1
# 7724       ai.exe                         running         9
# 7780       svchost.exe                    running         7
# 7800       cmd.exe                        running         1
# 7896       svchost.exe                    running         5
# 8172       WmiPrvSE.exe                   running         5
# 8488       chrome.exe                     running         7
# 8600       WmiPrvSE.exe                   running         11
# 8648       chrome.exe                     running         15
# 8852       svchost.exe                    running         9
# 8940       RuntimeBroker.exe              running         11
# 8976       Emc.Captiva.WebToolkitHost.exe running         7
# 8984       svchost.exe                    running         5
# 9096       audiodg.exe                    running         21
# 9108       Spotify.exe                    running         9
# 9188       svchost.exe                    running         8
# 9372       WmiPrvSE.exe                   running         3
# 9484       svchost.exe                    running         5
# 9592       chrome.exe                     running         18
# 9636       svchost.exe                    running         6
# 9724       RtkNGUI64.exe                  running         6
# 9820       chrome.exe                     running         11
# 9928       svchost.exe                    running         11
# 9940       ApplicationFrameHost.exe       running         2
# 9952       msedgewebview2.exe             running         20
# 10204      rundll32.exe                   running         1
# 10344      OfficeC2RClient.exe            running         10
# 10364      svchost.exe                    running         20
# 10368      TouchDR.exe                    running         4
# 10372      ETDTouch.exe                   running         2
# 10472      Code.exe                       running         14
# 10544      svchost.exe                    running         8
# 10556      Code.exe                       running         20
# 10564      Spotify.exe                    running         17
# 10660      dptf_helper.exe                running         3
# 10700      msedgewebview2.exe             running         19
# 10864      dwm.exe                        running         13
# 10956      msedgewebview2.exe             running         16
# 10996      RuntimeBroker.exe              running         3
# 11028      StartMenuExperienceHost.exe    running         10
# 11056      svchost.exe                    running         10
# 11084      conhost.exe                    running         5
# 11200      msedgewebview2.exe             running         16
# 11288      svchost.exe                    running         2
# 11576      RuntimeBroker.exe              running         1
# 11676      svchost.exe                    running         3
# 11752      svchost.exe                    running         3
# 11800      TrustedInstaller.exe           running         4
# 12008      SgrmBroker.exe                 running         8
# 12016      chrome.exe                     running         42
# 12364      SearchApp.exe                  stopped         36
# 12380      igfxEM.exe                     running         5
# 12468      chrome.exe                     running         20
# 12672      Code.exe                       running         22
# 12736      chrome.exe                     running         17
# 12760      Code.exe                       running         51
# 12820      Spotify.exe                    running         10
# 12828      CodeSetup-stable-f1a4fb101478ce6ec82fe9627c43efbf9e98c813.exe running         1
# 13384      dllhost.exe                    running         4
# 13436      chrome.exe                     running         16
# 13560      msedge.exe                     running         9
# 13652      msedge.exe                     running         13
# 13800      Code.exe                       running         17
# 13968      msedgewebview2.exe             running         48
# 14008      chrome.exe                     running         15
# 14016      msedge.exe                     running         50
# 14040      winlogon.exe                   running         6
# 14076      sihost.exe                     running         10
# 14368      dllhost.exe                    running         2
# 14460      RuntimeBroker.exe              running         4
# 14544      ms-teams.exe                   running         55
# 14928      conhost.exe                    running         2
# 15176      Code.exe                       running         20
# 15216      chrome.exe                     running         17
# 15260      svchost.exe                    running         5
# 15428      dllhost.exe                    running         5
# 15552      ETDCtrlHelper.exe              running         1
# 15560      svchost.exe                    running         3
# 15600      plugins_nms.exe                running         7
# 15664      dllhost.exe                    running         3
# 15924      TiWorker.exe                   running         2
# 16004      python3.12.exe                 running         5
# 16008      RuntimeBroker.exe              running         2
# 16096      chrome.exe                     running         15
# 16112      msedgewebview2.exe             running         7
# 16176      csrss.exe                      running         13
# 16224      conhost.exe                    running         3
# 16400      WhatsApp.exe                   stopped         19
# 16500      svchost.exe                    running         4
# 16576      UserOOBEBroker.exe             running         1
# 16716      MoUsoCoreWorker.exe            running         5
# 16880      fodhelper.exe                  running         1
# 16988      TextInputHost.exe              running         10
# 16992      Code.exe                       running         9
# 17532      CompPkgSrv.exe                 running         1
# 17580      Code.exe                       running         22
# 17860      ETDCtrl.exe                    running         11
# 17888      CodeSetup-stable-f1a4fb101478ce6ec82fe9627c43efbf9e98c813.tmp running         1
# 18012      chrome.exe                     running         10
# 18248      chrome.exe                     running         16
# 18356      powershell.exe                 running         11
# 18704      SecurityHealthSystray.exe      running         1
# 18784      RuntimeBroker.exe              running         2
# 19188      Spotify.exe                    running         9
# 19324      AnyDesk.exe                    running         9
# 19444      ms-teams.exe                   running         40
# 19620      Code.exe                       running         14
# 19636      chrome.exe                     running         19
# 19728      msedgewebview2.exe             running         9
# 20188      msedgewebview2.exe             running         8
# 20224      msedge.exe                     running         16
# 20300      backgroundTaskHost.exe         running         4
# 20320      chrome.exe                     running         16
# 20372      Spotify.exe                    running         85
# 20424      Code.exe                       running         21
# 20504      chrome.exe                     running         9
# 20552      chrome.exe                     running         15
# 20572      ctfmon.exe                     running         10
# 20660      python3.12.exe                 running         16
# 20712      fontdrvhost.exe                running         5
# 20988      Code.exe                       running         8
# 21036      conhost.exe                    running         2
# 21092      taskhostw.exe                  running         8
# 21100      Code.exe                       running         15
# 21276      explorer.exe                   running         60
# 21456      OneDrive.exe                   running         23
# 21616      taskhostw.exe                  running         6
# 21620      Spotify.exe                    running         18
# 21856      LockApp.exe                    stopped         14
# 22048      chrome.exe                     running         17
# 22252      svchost.exe                    running         5
# 22508      avpui.exe                      running         25
